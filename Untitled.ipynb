# %%
import os
import pandas as pd

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

from flask import Flask, jsonify, render_template
from flask_sqlalchemy import SQLAlchemy

# %%
app = Flask(__name__)

# %%
from config import password
rds_connection_string = ("root:"+password+"@127.0.0.1:3306/dallastraffic")
engine = create_engine('mysql://'+rds_connection_string)
        
final = pd.read_sql_query('select * from dallas_traffic', con=engine)
           
final.to_json()
# Out:
# '{"Type of Incident":{"0":"ACCIDENT INVOLVING INJURY","1":"ACCIDENT INVOLVING INJURY","2":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","3":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","4":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","5":"ACCIDENT INVOLVING SERIOUS BODILY INJURY","6":"ACCIDENT INVOLVING SERIOUS BODILY INJURY","7":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","8":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","9":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","10":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","11":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","12":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","13":"ACCIDENT INVOLVING INJURY","14":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","15":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","16":"ACCIDENT INVOLVING INJURY","17":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","18":"ACCIDENT INVOLVING INJURY","19":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","20":"ACCIDENT INVOLVING INJURY","21":"ACCIDENT INVOLVING INJURY","22":"ACCIDENT INVOLVING INJURY","23":"ACCIDENT INVOLVING DEATH","24":"ACCIDENT INVOLVING INJURY","25":"ACCIDENT INVOLVING INJURY","26":"ACCIDENT INVOLVING INJURY","27":"ACCIDENT INVOLVING INJURY","28":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","29":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","30":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","31":"ACCIDENT INVOLVING INJURY","32":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","33":"ACCIDENT INVOLVING INJURY","34":"ACCIDENT INVOLVING INJURY","35":"ACCIDENT INVOLVING INJURY","36":"ACCIDENT INVOLVING DEATH","37":"ACCIDENT INVOLVING INJURY","38":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","39":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","40":"ACCIDENT INVOLVING INJURY","41":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","42":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","43":"ACCIDENT INVOLVING SERIOUS BODILY INJURY","44":"ACCIDENT INVOLVING INJURY","45":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","46":"ACCIDENT INVOLVING INJURY","47":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","48":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","49":"ACCIDENT INVOLVING INJURY","50":"ACCIDENT INVOLVING INJURY","51":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","52":"ACCIDENT INVOLVING SERIOUS BODILY INJURY","53":"ACCIDENT INVOLVING SERIOUS BODILY INJURY","54":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","55":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","56":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","57":"ACCIDENT INVOLVING INJURY","58":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","59":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","60":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","61":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","62":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","63":"ACCIDENT INVOLVING INJURY","64":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","65":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","66":"ACCIDENT INVOLVING INJURY","67":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","68":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","69":"ACCIDENTAL DEATH (NO OFFENSE)","70":"ACCIDENT INVOLVING INJURY","71":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","72":"ACCIDENT INVOLVING INJURY","73":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","74":"ACCIDENTAL DEATH (NO OFFENSE)","75":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","76":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","77":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","78":"ACCIDENTAL DEATH (NO OFFENSE)","79":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","80":"ACCIDENT INVOLVING INJURY","81":"FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200","82":"ACCIDENT INVOLVING SERIOUS BODILY INJURY","83": ...

# %%
# Out:
# []
